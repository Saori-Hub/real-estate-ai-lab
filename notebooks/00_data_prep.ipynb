# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from pathlib import Path
from src.prepare_data import prepare_dataset

proj_root = Path("..").resolve()
RAW_PATH = proj_root / "data" / "raw" / "Tokyo_Suginami_Ward_20234_20253.csv"
PROCESSED_PATH = proj_root / "data" / "processed" / "Tokyo_Suginami_clean.csv"

df_use = prepare_dataset(RAW_PATH, PROCESSED_PATH)
df_use.head()
# Out:
#       price  area_sqm  station_minutes  year_built  building_age  \
# 0  76000000        85              2.0      2014.0          12.0
# 1  60000000        80              9.0      2007.0          19.0
# 2  64000000        75             11.0      2007.0          19.0
# 3  31000000        70             13.0      1974.0          52.0
# 4  12000000        20              5.0      1991.0          35.0
#
#   nearest_station
# 0             上井草
# 1              井荻
# 2              井荻
# 3             上井草
# 4             永福町
