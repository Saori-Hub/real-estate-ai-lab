# %%
import pandas as pd

data = {
    "price":[3200, 4500, 5100, 3900, 6200, 5800, 4700, 5200],
    "area":[40, 55, 60, 45, 70, 65, 50, 62]
}

df = pd.DataFrame(data)
df.to_csv("real_estate.csv", index=False)
df
# Out:
#    price  area
# 0   3200    40
# 1   4500    55
# 2   5100    60
# 3   3900    45
# 4   6200    70
# 5   5800    65
# 6   4700    50
# 7   5200    62

# %%
df = pd.read_csv("real_estate.csv")
df
# Out:
#    price  area
# 0   3200    40
# 1   4500    55
# 2   5100    60
# 3   3900    45
# 4   6200    70
# 5   5800    65
# 6   4700    50
# 7   5200    62

# %%
import matplotlib.pyplot as plt

plt.scatter(df["area"], df["price"])
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# データ（もしdfが消えていたら再作成）
data = {
    "price":[3200, 4500, 5100, 3900, 6200, 5800, 4700, 5200],
    "area":[40, 55, 60, 45, 70, 65, 50, 62]
}
df = pd.DataFrame(data)

X = df[["area"]]   # ←二重カッコが重要（2次元）
y = df["price"]

model = LinearRegression().fit(X, y)
pred = model.predict([[55]])[0]
pred
# Out:
# C:\Users\ninav\miniconda3\envs\ai\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(4744.16961130742)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

y_pred = model.predict(df[["area"]])
print("R2 =", r2_score(df["price"], y_pred))
print("MAE =", mean_absolute_error(df["price"], y_pred))
# Out:
# R2 = 0.9497246311872906
# MAE = 174.8864209994951

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error

# 学習用 / テスト用に分割
X = df[["area"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# 学習
model = LinearRegression()
model.fit(X_train, y_train)

# 予測（未知データ）
y_pred = model.predict(X_test)

print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# R2 = -2.141147588691592
# MAE = 283.47406513872147

# %%
import pandas as pd
import numpy as np

# データを増やす（50件）
np.random.seed(0)

area = np.random.randint(30, 80, 50)
price = area * 80 + np.random.normal(0, 200, 50)

df = pd.DataFrame({"area": area, "price": price})
df.head()
# Out:
#    area        price
# 0    74  6038.248561
# 1    77  6003.444899
# 2    30  2311.153435
# 3    33  2570.962768
# 4    33  2463.639890

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# 入力と出力
X = df[["area"]]
y = df["price"]

# 学習用 / テスト用に分割
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# モデル学習
model = LinearRegression()
model.fit(X_train, y_train)

# 予測
y_pred = model.predict(X_test)

# 精度評価
print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# R2 = 0.9714936088135883
# MAE = 154.0334512402515

# %%
np.random.seed(0)

area = np.random.randint(30, 80, 100)
age = np.random.randint(0, 30, 100)        # 築年数
station = np.random.randint(1, 15, 100)    # 駅距離

price = area*85 - age*20 - station*30 + np.random.normal(0,150,100)

df = pd.DataFrame({
    "area": area,
    "age": age,
    "station": station,
    "price": price
})

# %%
X = df[["area","age","station"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# R2 = 0.9828328196252042
# MAE = 105.92933358574861

# %%
pd.DataFrame({
    "feature": X.columns,
    "weight": model.coef_
})
# Out:
#    feature     weight
# 0     area  85.577218
# 1      age -21.893934
# 2  station -28.936357

# %%
model.predict([[60, 10, 5]])
# Out:
# C:\Users\ninav\miniconda3\envs\ai\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4769.53878972])

# %%
pd.DataFrame({
    "feature": ["area"],
    "weight": model.coef_
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.DataFrame({
#       2     "feature": ["area"],
#       3     "weight": model.coef_
#       4 })
#
# File ~\miniconda3\envs\ai\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File ~\miniconda3\envs\ai\Lib\site-packages\pandas\core\internals\construction.py:447, in dict_to_mgr(data, index, columns, dtype, copy)
# ...

# %%
import numpy as np

np.random.seed(0)

area = np.random.randint(30, 80, 100)
age = np.random.randint(0, 30, 100)
station = np.random.randint(1, 15, 100)

price = area*85 - age*20 - station*30 + np.random.normal(0,150,100)

df = pd.DataFrame({
    "area": area,
    "age": age,
    "station": station,
    "price": price
})

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

X = df[["area","age","station"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# R2 = 0.9828328196252042
# MAE = 105.92933358574861

# %%
pd.DataFrame({
    "feature": X.columns,
    "weight": model.coef_
})
# Out:
#    feature     weight
# 0     area  85.577218
# 1      age -21.893934
# 2  station -28.936357

# %%
model.predict([[60, 10, 5]])
# Out:
# C:\Users\ninav\miniconda3\envs\ai\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4769.53878972])

# %%
# ==============================
# 学習データとテストデータに分割
# ==============================
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

X = df[["area","age","station"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# ==============================
# モデル学習
# ==============================
model = LinearRegression()
model.fit(X_train, y_train)

# ==============================
# テストデータで予測
# ==============================
y_pred = model.predict(X_test)

print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 from sklearn.linear_model import LinearRegression
#       6 from sklearn.metrics import r2_score, mean_absolute_error
# ----> 8 X = df[["area","age","station"]]
#       9 y = df["price"]
#      11 X_train, X_test, y_train, y_test = train_test_split(
#      12     X, y, test_size=0.25, random_state=0
#      13 )
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

area = np.random.randint(30, 80, 100)
age = np.random.randint(0, 30, 100)
station = np.random.randint(1, 15, 100)

price = area*85 - age*20 - station*30 + np.random.normal(0,150,100)

df = pd.DataFrame({
    "area": area,
    "age": age,
    "station": station,
    "price": price
})

df.head()
# Out:
#    area  age  station        price
# 0    74    5        6  6169.142673
# 1    77    9       10  6049.471626
# 2    30    3        1  2481.272524
# 3    33    0       13  2502.272962
# 4    33    5       10  2608.181096

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

X = df[["area","age","station"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("R2 =", r2_score(y_test, y_pred))
print("MAE =", mean_absolute_error(y_test, y_pred))
# Out:
# R2 = 0.9828328196252042
# MAE = 105.92933358574861

# %%
pd.DataFrame({
    "feature": X.columns,
    "weight": model.coef_
})
# Out:
#    feature     weight
# 0     area  85.577218
# 1      age -21.893934
# 2  station -28.936357
